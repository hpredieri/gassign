# %%
import pandas as pd
import seaborn as sns
import numpy as np
from __future__ import division
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.options.display.mpl_style = 'default'

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
url = 'https://raw.githubusercontent.com/podopie/DAT18NYC/master/data/bikeshare.csv'
bike_data = pd.read_csv(url)
bike_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0        1  2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81          0       3          13   16
# 1        2  2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80          0       8          32   40
# 2        3  2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80          0       5          27   32
# 3        4  2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75          0       3          10   13
# 4        5  2011-01-01       1   0     1   4        0        6           0           1  0.24  0.2879  0.75          0       0           1    1

# %%
daily = bike_data.groupby('dteday')

# %%
daily.head()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0            1  2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81     0.0000       3          13   16
# 1            2  2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80     0.0000       8          32   40
# 2            3  2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80     0.0000       5          27   32
# 3            4  2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75     0.0000       3          10   13
# 4            5  2011-01-01       1   0     1   4        0        6           0           1  0.24  0.2879  0.75     0.0000       0           1    1
# ...

# %%
daily.describe()
# Out:
#                        instant  season  yr  mnth         hr  holiday  weekday  workingday  weathersit       temp         atemp        hum  windspeed      casual  registered         cnt
# dteday
# 2011-01-01 count     24.000000      24  24    24  24.000000       24       24          24   24.000000  24.000000  2.400000e+01  24.000000  24.000000   24.000000   24.000000   24.000000
#            mean      12.500000       1   0     1  11.500000        0        6           0    1.583333   0.344167  3.636250e-01   0.805833   0.160446   13.791667   27.250000   41.041667
#            std        7.071068       0   0     0   7.071068        0        0           0    0.653863   0.096545  7.501492e-02   0.059044   0.134091   14.455266   21.303705   34.292196
#            min        1.000000       1   0     1   0.000000        0        6           0    1.000000   0.200000  2.576000e-01   0.720000   0.000000    0.000000    0.000000    1.000000
# ...

# %%
daily

# %%
bike_data.per_reg = [bike_data.registered / bike_data.cnt]

# %%
bike_data.per_reg
# Out:
# [0     0.812500
#  1     0.800000
#  2     0.843750
#  3     0.769231
#  4     1.000000
#  5     1.000000
#  6     0.000000
#  7     0.666667
#  8     0.875000
#  9     0.428571
#  10    0.666667
#  11    0.535714
#  12    0.654762
#  13    0.500000
#  14    0.669811
#  ...
#  17364    0.917197
#  17365    0.725000
#  17366    0.726115
#  17367    0.767857
#  17368    0.812808
#  17369    0.748988
#  17370    0.780952
#  17371    0.859813
#  17372    0.914634
#  17373    0.918033
#  17374    0.907563
#  17375    0.910112
#  17376    0.922222
#  17377    0.786885
#  17378    0.755102
#  Length: 17379, dtype: float64]

# %%
bike_data.per_nreg = [1- i for i in bike_data.per_reg]
bike_data.per_nreg
# Out:
# [0     0.187500
#  1     0.200000
#  2     0.156250
#  3     0.230769
#  4     0.000000
#  5     0.000000
#  6     1.000000
#  7     0.333333
#  8     0.125000
#  9     0.571429
#  10    0.333333
#  11    0.464286
#  12    0.345238
#  13    0.500000
#  14    0.330189
#  ...
#  17364    0.082803
#  17365    0.275000
#  17366    0.273885
#  17367    0.232143
#  17368    0.187192
#  17369    0.251012
#  17370    0.219048
#  17371    0.140187
#  17372    0.085366
#  17373    0.081967
#  17374    0.092437
#  17375    0.089888
#  17376    0.077778
#  17377    0.213115
#  17378    0.244898
#  Length: 17379, dtype: float64]

# %%
bike_data.sum()
# Out:
# instant                                               151023510
# dteday        2011-01-012011-01-012011-01-012011-01-012011-0...
# season                                                    43476
# yr                                                         8734
# mnth                                                     113620
# hr                                                       200671
# holiday                                                     500
# weekday                                                   52201
# workingday                                                11865
# weathersit                                                24770
# temp                                                    8637.14
# atemp                                                  8268.495
# hum                                                    10900.61
# windspeed                                              3303.706
# casual                                                   620017
# ...

# %%
daily.sum()
# Out:
#             instant  season  yr  mnth   hr  holiday  weekday  workingday  weathersit   temp    atemp    hum  windspeed  casual  registered   cnt
# dteday
# 2011-01-01      300      24   0    24  276        0      144           0          38   8.26   8.7270  19.34     3.8507     331         654   985
# 2011-01-02      828      23   0    23  271        0        0           0          45   8.36   8.1360  16.01     5.7164     131         670   801
# 2011-01-03     1287      22   0    22  271        0       22          22          22   4.32   4.1669   9.62     5.4628     120        1229  1349
# 2011-01-04     1863      23   0    23  273        0       46          23          24   4.60   4.8788  13.58     3.6868     108        1454  1562
# 2011-01-05     2392      23   0    23  273        0       69          23          23   5.22   5.2732  10.05     4.2987      82        1518  1600
# ...

# %%
dailytotal = daily.sum()

# %%
dailytotal.describe()
# Out:
#              instant      season          yr        mnth          hr     holiday     weekday  workingday  weathersit        temp       atemp         hum   windspeed       casual   registered          cnt
# count     731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000   731.000000   731.000000   731.000000
# mean   206598.508892   59.474692   11.948016  155.430917  274.515732    0.683995   71.410397   16.231190   33.885089   11.815513   11.311211   14.911915    4.519434   848.176471  3656.172367  4504.348837
# std    120983.715339   26.849716   11.980236   82.993904   13.506800    3.980432   48.120723   11.116071   10.257263    4.460872    3.983894    3.463559    1.845342   686.622488  1560.256377  1937.211452
# ...

# %%
del dailytotal['instant']

# %%
dailytotal.describe()
# Out:
#            season          yr        mnth          hr     holiday     weekday  workingday  weathersit        temp       atemp         hum   windspeed       casual   registered          cnt
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000   731.000000   731.000000   731.000000
# mean    59.474692   11.948016  155.430917  274.515732    0.683995   71.410397   16.231190   33.885089   11.815513   11.311211   14.911915    4.519434   848.176471  3656.172367  4504.348837
# std     26.849716   11.980236   82.993904   13.506800    3.980432   48.120723   11.116071   10.257263    4.460872    3.983894    3.463559    1.845342   686.622488  1560.256377  1937.211452
# min      4.000000    0.000000    8.000000    0.000000    0.000000    0.000000    0.000000    3.000000    0.440000    0.439400    0.000000    0.358200     2.000000    20.000000    22.000000
# ...

# %%
hourly = bike_data.groupby('hr')

# %%
hourly.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-baa50dd23ddc> in <module>()
# ----> 1 hourly.value_counts()
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\groupby.pyc in __getattr__(self, attr)
#     509
#     510         raise AttributeError("%r object has no attribute %r" %
# --> 511                              (type(self).__name__, attr))
#     512
#     513     def __getitem__(self, key):
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'value_counts'

# %%
bike_data.temp.value_counts()
# Out:
# 0.62    726
# 0.66    693
# 0.64    692
# 0.70    690
# 0.60    675
# 0.36    671
# 0.34    645
# 0.30    641
# 0.40    614
# 0.32    611
# 0.56    579
# 0.72    570
# 0.54    569
# 0.46    559
# 0.26    559
# 0.52    556
# 0.42    548
# 0.50    531
# 0.24    522
# 0.74    516
# 0.44    507
# 0.22    421
# 0.76    396
# 0.38    372
# 0.20    354
# 0.68    349
# 0.80    325
# 0.58    305
# 0.28    301
# 0.48    288
# 0.16    230
# 0.82    213
# 0.78    169
# 0.18    155
# 0.84    138
# 0.14    138
# 0.86    131
# 0.90     90
# 0.12     76
# 0.88     53
# 0.10     51
# 0.92     49
# 0.02     17
# 0.08     17
# 0.94     17
# 0.96     16
# 0.04     16
# 0.06     16
# 0.98      1
# 1.00      1
# dtype: int64

# %%
work_day = bike_data.groupby('workingday')

# %%
work_day.describe()
# Out:
#                          atemp        casual           cnt       holiday            hr           hum       instant          mnth    registered        season          temp    weathersit       weekday     windspeed            yr
# workingday
# 0          count   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000   5514.000000
#            mean       0.461995     57.441422    181.405332      0.090678     11.523576      0.622789   8715.136017      6.555314    123.963910      2.479325      0.481342      1.383388      2.897896      0.192221      0.504171
#            std        0.176340     71.713021    172.853832      0.287177      6.915775      0.191229   5063.088910      3.518076    107.779533      1.127476      0.196544      0.612394      2.912333      0.122959      0.500028
# ...

# %%
print hourly[['registered', 'casual']].mean()
print daily[['registered', 'casual']].mean()
# Out:
#     registered     casual
# hr
# 0    43.739669  10.158402
# 1    26.871547   6.504144
# 2    18.097902   4.772028
# 3     9.011478   2.715925
# 4     5.098996   1.253945
# 5    18.478382   1.411437
# 6    71.882759   4.161379
# 7   201.009629  11.055021
# 8   337.331499  21.679505
# 9   188.418157  30.891334
# 10  127.191197  46.477304
# 11  148.602476  59.540578
# 12  185.021978  68.293956
# 13  181.352538  72.308642
# 14  165.381344  75.567901
# 15  176.327846  74.905350
# 16  238.238356  73.745205
# 17  387.178082  74.273973
# 18  364.390110  61.120879
# 19  262.752747  48.770604
# 20  189.796703  36.233516
# 21  144.059066  28.255495
# 22  109.082418  22.252747
# 23   72.631868  15.199176
#             registered      casual
# dteday
# 2011-01-01   27.250000   13.791667
# 2011-01-02   29.130435    5.695652
# 2011-01-03   55.863636    5.454545
# 2011-01-04   63.217391    4.695652
# 2011-01-05   66.000000    3.565217
# 2011-01-06   66.000000    3.826087
# ...

# %%
reg_hist = hourly[['registered', 'casual']].mean()
reg_hist.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10601E50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1054B2D0>]], dtype=object)

# %%
plt.figure(figsize=(8, 6), dpi=80)
reg_hist.boxplot()
# Out:
# c:\Users\owner\Anaconda\lib\site-packages\pandas\tools\plotting.py:2625: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)
# {'boxes': [<matplotlib.lines.Line2D at 0x10fc07d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x10fcf030>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x10fcf9f0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x10fcf6b0>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x10fc0950>,
# ...
#   <matplotlib.lines.Line2D at 0x10fd83b0>]}

# %%
daily2 = bike_data.groupby('weekday')

# %%
daily2[['registered', 'casual']].mean()
# Out:
#          registered     casual
# weekday
# 0        121.305356  56.163469
# 1        155.191206  28.553449
# 2        167.658377  23.580514
# 3        167.971313  23.159192
# 4        171.564144  24.872521
# 5        164.677121  31.458786
# 6        128.962978  61.246815

# %%
bike_data['percent_registered']= (bike_data.registered / bike_data.cnt)

# %%
bike_data['percent_casual'] = (bike_data.casual / bike_data.cnt)

# %%
bike_data.head)()
# Out:
#   File "<ipython-input-62-c83ded598345>", line 1
#     bike_data.head)()
#                   ^
# SyntaxError: invalid syntax

# %%
bike_data.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  percent_registered  percent_casual
# 0        1  2011-01-01       1   0     1   0        0        6           0           1  0.24  0.2879  0.81          0       3          13   16            0.812500        0.187500
# 1        2  2011-01-01       1   0     1   1        0        6           0           1  0.22  0.2727  0.80          0       8          32   40            0.800000        0.200000
# 2        3  2011-01-01       1   0     1   2        0        6           0           1  0.22  0.2727  0.80          0       5          27   32            0.843750        0.156250
# 3        4  2011-01-01       1   0     1   3        0        6           0           1  0.24  0.2879  0.75          0       3          10   13            0.769231        0.230769
# ...

# %%
daily.temp

# %%
get = daily.groupby(['temp']).apply(level = 0, group_keys=False)
get_final = get.apply(lambda x: x.order(ascending=True)).head(10)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-77-c438e3fb3e3b> in <module>()
# ----> 1 get = bike_data.groupby(['casual','temp']).apply(level = 0, group_keys=False)
#       2 get_final = get.apply(lambda x: x.order(ascending=True)).head(10)
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    2896         axis = self._get_axis_number(axis)
#    2897         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
# -> 2898                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#    2899
#    2900     def asfreq(self, freq, method=None, how=None, normalize=False):
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\groupby.pyc in groupby(obj, by, **kwds)
#    1191         raise TypeError('invalid type: %s' % type(obj))
#    1192
# ...

# %%
daily.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-78-6497c2a63ad6> in <module>()
# ----> 1 daily.head()
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\groupby.pyc in head(self, n)
#     985         obj = self._selected_obj
#     986         in_head = self._cumcount_array() < n
# --> 987         head = obj[in_head]
#     988         return head
#     989
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1772         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1773             # either boolean or fancy integer index
# -> 1774             return self._getitem_array(key)
#    1775         elif isinstance(key, DataFrame):
#    1776             return self._getitem_frame(key)
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
# ...

# %%
bike_data.sort_index('temp')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-b1cf9952af08> in <module>()
# ----> 1 bike_data.sort_index('temp')
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\frame.pyc in sort_index(self, axis, by, ascending, inplace, kind, na_position)
#    2833
#    2834         from pandas.core.groupby import _lexsort_indexer, _nargsort
# -> 2835         axis = self._get_axis_number(axis)
#    2836         if axis not in [0, 1]:  # pragma: no cover
#    2837             raise AssertionError('Axis must be 0 or 1, got %s' % str(axis))
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\generic.pyc in _get_axis_number(self, axis)
#     294                 pass
#     295         raise ValueError('No axis named {0} for object type {1}'
# --> 296                          .format(axis, type(self)))
#     297
#     298     def _get_axis_name(self, axis):
#
# ...

# %%
hourly.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-80-4058c350e60b> in <module>()
# ----> 1 hourly.head()
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\groupby.pyc in head(self, n)
#     985         obj = self._selected_obj
#     986         in_head = self._cumcount_array() < n
# --> 987         head = obj[in_head]
#     988         return head
#     989
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1772         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1773             # either boolean or fancy integer index
# -> 1774             return self._getitem_array(key)
#    1775         elif isinstance(key, DataFrame):
#    1776             return self._getitem_frame(key)
#
# c:\Users\owner\Anaconda\lib\site-packages\pandas\core\frame.pyc in _getitem_array(self, key)
# ...
