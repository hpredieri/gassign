# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nba_norm = 'C:/Users/owner/gassign/nba_normal.csv'
col_names = ['event_txt', 'avg', 'opp_ranking', 'home_ranking', 'ppg', 'opp_rpi', 'delta_rpi', 'home_pop', 'home_attend', 'beer_price']
df =pd.read_csv(nba_norm, names=col_names, header=True)

# %%
df.head()
# Out:
#          event_txt       avg  opp_ranking  home_ranking       ppg  opp_rpi  \
# 1      76ers_Bulls  0.283872            0           1.0  0.829535    0.434
# 2  76ers_Cavaliers  0.564896            0           1.0  0.829535    0.434
# 3    76ers_Celtics  0.411995            0           0.5  0.829535    0.434
# 4    76ers_Hornets  0.643639            0           0.5  0.829535    0.434
# 5     76ers_Knicks  0.520315            0           0.0  0.829535    0.434
#
#    delta_rpi  home_pop  home_attend  beer_price
# 1      0.086  0.635232        1.014    0.761905
# 2      0.099 -0.689461        1.000    0.380952
# 3      0.045 -0.205255        0.935    0.809524
# 4      0.048 -0.734019        0.912    0.619048
# 5      0.016  2.696743        1.000    1.000000

# %%
names = df.columns.tolist()
names[names.index('avg')] = 'target'
df.columns = names
print names
# Out:
# ['event_txt', 'target', 'opp_ranking', 'home_ranking', 'ppg', 'opp_rpi', 'delta_rpi', 'home_pop', 'home_attend', 'beer_price']

# %%
df4 = df.copy()

# %%
df4.drop('event_txt', axis=1)
# Out:
#        target  opp_ranking  home_ranking       ppg  opp_rpi  delta_rpi  \
# 1    0.283872          0.0           1.0  0.829535    0.434      0.086
# 2    0.564896          0.0           1.0  0.829535    0.434      0.099
# 3    0.411995          0.0           0.5  0.829535    0.434      0.045
# 4    0.643639          0.0           0.5  0.829535    0.434      0.048
# 5    0.520315          0.0           0.0  0.829535    0.434      0.016
# 6    0.547856          0.0           0.0  0.829535    0.434      0.019
# 7    0.326871          0.0           0.0  0.829535    0.434      0.040
# 8    0.541284          0.0           0.5  0.829535    0.434      0.046
# 9    0.753247          0.0           0.5  0.829535    0.434      0.083
# 10   0.388171          0.0           1.0  0.829535    0.434      0.075
# 11   0.454779          0.5           0.0  0.889699    0.495      0.061
# 12   0.370887          0.5           0.5  0.889699    0.495      0.016
# ...

# %%
x_cols = names.remove('target')

# %%
x_cols = names
print x_cols
# Out:
# ['event_txt', 'opp_ranking', 'home_ranking', 'ppg', 'opp_rpi', 'delta_rpi', 'home_pop', 'home_attend', 'beer_price']

# %%
y_col = df4.target

# %%
from sklearn import feature_selection

# %%
from sklearn.cross_validation
